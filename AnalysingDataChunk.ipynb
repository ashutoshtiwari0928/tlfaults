# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("OptimizedDataset.csv")

# %%
df.isna().any()
# Out:
# Number            False
# IaL12             False
# IbL12             False
# IcL12             False
# Ia13              False
# Ib13              False
# Ic13              False
# Ia23              False
# Ib23              False
# Ic23              False
# Ia24              False
# Ib24              False
# Ic24              False
# Ia25              False
# Ib25              False
# Ic25              False
# Ia34              False
# Ib34              False
# Ic34              False
# Ia45              False
# Ib45              False
# Ic45              False
# Va12              False
# Vb12              False
# Vc12              False
# Va13              False
# Vb13              False
# Vc13              False
# Va23              False
# Vb23              False
# Vc23              False
# Va24              False
# Vb24              False
# Vc24              False
# Va25              False
# Vb25              False
# Vc25              False
# Va34              False
# ...

# %%
df.isnull().sum()
# Out:
# Number            0
# IaL12             0
# IbL12             0
# IcL12             0
# Ia13              0
# Ib13              0
# Ic13              0
# Ia23              0
# Ib23              0
# Ic23              0
# Ia24              0
# Ib24              0
# Ic24              0
# Ia25              0
# Ib25              0
# Ic25              0
# Ia34              0
# Ib34              0
# Ic34              0
# Ia45              0
# Ib45              0
# Ic45              0
# Va12              0
# Vb12              0
# Vc12              0
# Va13              0
# Vb13              0
# Vc13              0
# Va23              0
# Vb23              0
# Vc23              0
# Va24              0
# Vb24              0
# Vc24              0
# Va25              0
# Vb25              0
# Vc25              0
# Va34              0
# Vb34              0
# Vc34              0
# Va45              0
# Vb45              0
# Vc45              0
# Type of Fault     0
# Fault Location    0
# ...

# %%
df["Fault Location"].nunique()
# Out:
# 8

# %%
df["Type of Fault"].unique()
# Out:
# array(['No fault', 'L-L', 'SLG', 'L-L-L', 'L-L-L-G', 'Line fault', 'DLG'],
#       dtype=object)

# %%
df["Type of Fault"].hist()
# Out:
# <AxesSubplot: >

# %%
df["Fault Location"].hist()
# Out:
# <AxesSubplot: >

# %%
df
# Out:
#               Number      IaL12      IbL12      IcL12       Ia13      Ib13  \
# 0       0.000000e+00  145.27620 -5989.7183  5844.4420 -418.73236 -7188.270
# 1       2.223606e-08  145.33347 -5989.7456  5844.4120 -418.66077 -7188.309
# 2       1.334164e-07  145.61984 -5989.8840  5844.2637 -418.30273 -7188.503
# 3       6.893179e-07  147.05171 -5990.5730  5843.5215 -416.51257 -7189.474
# 4       3.468825e-06  154.21097 -5994.0160  5839.8050 -407.56143 -7194.323
# ...              ...        ...        ...        ...        ...       ...
# 578918           NaN        NaN        NaN        NaN        NaN       NaN
# 578919           NaN        NaN        NaN        NaN        NaN       NaN
# 578920           NaN        NaN        NaN        NaN        NaN       NaN
# 578921           NaN        NaN        NaN        NaN        NaN       NaN
# 578922           NaN        NaN        NaN        NaN        NaN       NaN
#
# ...
